# %%
import pandas as pd
import numpy as np
from deconv.figures.common import subplotLabel, getSetup
from deconv.imports import load_tables, infer_x, load_bindingData

# %%
fig2A, fig2B, fig2C, fig2D, fig2E, fig2F, fig2G, fig2H = load_bindingData()
A_antiD, A_antiTNP, glycan_list, mixtures = load_tables()

# %%
ax, f = getSetup((10, 5), (2, 4))

# %%
mean_2A = []
mean_2B = []
mean_2C = []
mean_2D = []
mean_2E = []
mean_2F = []
mean_2G = []
mean_2H = []

# %%
for x in np.arange(len(mixtures)):
    mean_2A.append(np.nanmean(fig2A[:, x]))
    mean_2B.append(np.nanmean(fig2B[:, x]))
    mean_2C.append(np.nanmean(fig2C[:, x]))
    mean_2D.append(np.nanmean(fig2D[:, x]))
    mean_2E.append(np.nanmean(fig2E[:, x]))
    mean_2F.append(np.nanmean(fig2F[:, x]))
    mean_2G.append(np.nanmean(fig2G[:, x]))
    mean_2H.append(np.nanmean(fig2H[:, x]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-4d8cb1e83532> in <module>
#       1 for x in np.arange(len(mixtures)):
#       2     mean_2A.append(np.nanmean(fig2A[:, x]))
# ----> 3     mean_2B.append(np.nanmean(fig2B[:, x]))
#       4     mean_2C.append(np.nanmean(fig2C[:, x]))
#       5     mean_2D.append(np.nanmean(fig2D[:, x]))
#
# <__array_function__ internals> in nanmean(*args, **kwargs)
#
# /usr/local/lib/python3.8/site-packages/numpy/lib/nanfunctions.py in nanmean(a, axis, dtype, out, keepdims)
#     947
#     948     cnt = np.sum(~mask, axis=axis, dtype=np.intp, keepdims=keepdims)
# --> 949     tot = np.sum(arr, axis=axis, dtype=dtype, out=out, keepdims=keepdims)
#     950     avg = _divide_by_count(tot, cnt, out=out)
#     951
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# /usr/local/lib/python3.8/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2245         return res
#    2246
# -> 2247     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2248                           initial=initial, where=where)
#    2249
#
# /usr/local/lib/python3.8/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
glycans_2A = infer_x(A_antiD, mean_2A)

# %%
ax[0].bar(glycan_list, glycans_2A)
ax[0].set_title("FcgRI Binding (Fig. 2A)")
ax[0].set_xlabel("Glycans")
ax[0].set_xticklabels(glycan_list, rotation=90)
# Out:
# <ipython-input-8-1505ea6fff0d>:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels(glycan_list, rotation=90)
# [Text(0, 0, 'G0F'),
#  Text(1, 0, 'G1F'),
#  Text(2, 0, 'G2F'),
#  Text(3, 0, 'G0FN'),
#  Text(4, 0, 'G1FN'),
#  Text(5, 0, 'G2FN'),
#  Text(6, 0, 'G1FS'),
#  Text(7, 0, 'G2FS'),
#  Text(8, 0, 'G2FS2'),
#  Text(9, 0, 'G1FNS'),
#  Text(10, 0, 'G2FNS'),
#  Text(11, 0, 'G2FNS2'),
#  Text(12, 0, 'G0'),
#  Text(13, 0, 'G1'),
#  Text(14, 0, 'G2'),
#  Text(15, 0, 'G0N'),
#  Text(16, 0, 'G1N'),
#  Text(17, 0, 'G2N'),
#  Text(18, 0, 'G1S'),
#  Text(19, 0, 'G2S'),
#  Text(20, 0, 'G2S2'),
#  Text(21, 0, 'G1NS'),
#  Text(22, 0, 'G2NS'),
#  Text(23, 0, 'G2NS2')]

# %%
f
